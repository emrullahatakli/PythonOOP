# %%
class Item:
    def calculate_total_price(self, x, y):
        return x * y

item1 = Item()
item1.name = "phone"
item1.price = 100
item1.quantity = 5

print(type(item1))
print(type(item1.name))
print(type(item1.price))
print(item1.calculate_total_price(item1.price, item1.quantity))
# Out:
# <class '__main__.Item'>
# <class 'str'>
# <class 'int'>
# 500

# %%
#__init__ fonksiyonu class yaratıldığında ilk çağırılan fonksiyondur.
#yarattığımız sınıfta ortak olmayan bir özellik varsa kendimiz ekleyebiliriz.
#init methodumuzda argümanlara tiplerini belirtebiliriz.
#quantity zaten 0'a eşit olduğundan tipi int olarak otomatik belirlendi.
#assert ile istemediğimiz değerleri almayabiliriz.


class Item:
    pay_rate = 0.8 # %20 discount
    def __init__(self, name: str, price: float, quantity = 0):
        assert price >= 0, f"Price {price} is not greater than or equal to zero" 
        assert quantity >= 0, f"Quantity {quantity} is not greater than or equal to zero"
        
        self.name = name
        self.price = price
        self.quantity = quantity
        
    def calculate_total_price(self):
        return self.price * self.quantity
    
item1 = Item("phone", 100, 1)
item2 = Item("laptop", 1000, 3)
item3 = Item("Tv", 3000, 5)

item3.is_fhd = True

print(item3.is_fhd)
print(item1.calculate_total_price())
print(item2.calculate_total_price())


#pay_rate class attributedur. instancelera atanmamıştır.
print(Item.pay_rate, "\n")
print(Item.__dict__, "\n")
print(item1.__dict__)
#dict class ve instancedaki attributelerı döndürür.
# Out:
# True
# 100
# 3000
# 0.8
#
# {'__module__': '__main__', 'pay_rate': 0.8, '__init__': <function Item.__init__ at 0x7fb99318f5e0>, 'calculate_total_price': <function Item.calculate_total_price at 0x7fb99318fa60>, '__dict__': <attribute '__dict__' of 'Item' objects>, '__weakref__': <attribute '__weakref__' of 'Item' objects>, '__doc__': None}
#
# {'name': 'phone', 'price': 100, 'quantity': 1}

# %%
class Item:
    pay_rate = 0.8 # %20 discount
    def __init__(self, name: str, price: float, quantity = 0):
        assert price >= 0, f"Price {price} is not greater than or equal to zero" 
        assert quantity >= 0, f"Quantity {quantity} is not greater than or equal to zero"
        
        self.name = name
        self.price = price
        self.quantity = quantity
        
    def calculate_total_price(self):
        return self.price * self.quantity
    
    def apply_discount(self):
        self.price = self.price * self.pay_rate
    
item1 = Item("phone", 100, 1)
item2 = Item("laptop", 1000, 3)

item1.apply_discount()
print(item1.price)

#item2ye farklı bi discount uygulamak istiyorum.

item2.pay_rate = 0.7

item2.apply_discount()
print(item2.price)

#gördüğümüz gibi yüzde30 indirim yapmadı çünkü bizim pay ratemiz instance leveldedir.
#bu yüzden fonkisyonumuzu Item.pay_rate yerine self.pay_rate yaparsak daha verimli olacaktır.
#bu şekilde iki farklı pay_rate oranı aktive oluyor.
# Out:
# 80.0
# 700.0

# %%
class Item:
    pay_rate = 0.8 # %20 discount
    all = []
    def __init__(self, name: str, price: float, quantity = 0):
        assert price >= 0, f"Price {price} is not greater than or equal to zero" 
        assert quantity >= 0, f"Quantity {quantity} is not greater than or equal to zero"
        
        self.name = name
        self.price = price
        self.quantity = quantity
        
        Item.all.append(self)
        
    def calculate_total_price(self):
        return self.price * self.quantity
    
    def apply_discount(self):
        self.price = self.price * self.pay_rate
    
    def __repr__(self):
        return f"Item('{self.name}', {self.price}, {self.quantity})"
        
        
item1 = Item("Phone", 100, 1)
item2 = Item("Laptop", 1000, 3)
item3 = Item("Cable", 10, 5)
item4 = Item("Mouse", 50, 5)
item5 = Item("Keyboard", 75, 5)

print(Item.all)

#Bu yöntemle instancelarımızı görüntülüyebiliriz.
"""
ya da bu şekilde döndürebiliriz.

for instance in Item.all:
    print(instance.name)

"""
# Out:
# [Item('Phone', 100, 1), Item('Laptop', 1000, 3), Item('Cable', 10, 5), Item('Mouse', 50, 5), Item('Keyboard', 75, 5)]

# %%
import csv

# %%
class Item:
    pay_rate = 0.8
    all = []
    def __init__(self, name: str, price: float, quantity = 0):
        assert price >= 0, f"Price {price} is not greater than or equal to zero" 
        assert quantity >= 0, f"Quantity {quantity} is not greater than or equal to zero"
                
        self.name = name
        self.price = price
        self.quantity = quantity
        
        Item.all.append(self)
        
    def calculate_total_price(self):
        return self.price * self.quantity
    
    def apply_discount(self):
        self.price = self.price * self.pay_rate
    
    @classmethod
    def instantiate_from_csv(cls):
        with open('items.csv', 'r') as f:
            reader = csv.DictReader(f)
            items = list(reader)
        
        for item in items:
            Item(
                name = item.get("name"),
                price = float(item.get("price")),
                quantity = int(item.get("quantity"))
            )
    
    
    def __repr__(self):
        return f"Item('{self.name}', '{self.price}', '{self.quantity}')"
    
Item.instantiate_from_csv()
print(Item.all)

#@classmethod bir decarator'dür.
#class methodu oluşturmak istediğimiz zaman fonksiyonun üstünde belirtiriz.
#methodu instance bazında çağıramıycağımız için class methodu oluşturmak lazım.
#bunu da decatorle yapıyoruz.
# Out:
# [Item('Phone', '100.0', '1'), Item('Laptop', '1000.0', '3'), Item('Cable', '10.0', '5'), Item('Mouse', '50.0', '5'), Item('Keyboard', '75.0', '5')]

# %%
class Item:
    pay_rate = 0.8
    all = []
    def __init__(self, name: str, price: float, quantity = 0):
        assert price >= 0, f"Price {price} is not greater than or equal to zero" 
        assert quantity >= 0, f"Quantity {quantity} is not greater than or equal to zero"
                
        self.name = name
        self.price = price
        self.quantity = quantity
        
        Item.all.append(self)
        
    def calculate_total_price(self):
        return self.price * self.quantity
    
    def apply_discount(self):
        self.price = self.price * self.pay_rate
    
    @classmethod
    def instantiate_from_csv(cls):
        with open('items.csv', 'r') as f:
            reader = csv.DictReader(f)
            items = list(reader)
        
        for item in items:
            Item(
                name = item.get("name"),
                price = float(item.get("price")),
                quantity = int(item.get("quantity"))
            )
            
    @staticmethod
    def is_integer(num):
        if isinstance(num, float):
            return num.is_integer()
        
        elif isinstance(num, int):
            return True
        
        else:
            return False
            
            
    def __repr__(self):
        return f"Item('{self.name}', '{self.price}', '{self.quantity}')"

print(Item.is_integer(8))
print(Item.is_integer(7.5))
print(Item.is_integer(7.0))

#staticmethodda argüman olarak self ya da cls almak zorunda değildir.
#classmethod, staticmethoda göre classlarla daha çok ilgildir.
#isinstance -> aldığı ilk argümanın ikinci argüman tipinde olup olmadığını kontrol eder.
#is_integer -> sadece float veritipini float mı değil mi diye true false döndürür.
# Out:
# True
# False
# True

# %%
class Item:
    pay_rate = 0.8
    all = []
    def __init__(self, name: str, price: float, quantity = 0):
        assert price >= 0, f"Price {price} is not greater than or equal to zero" 
        assert quantity >= 0, f"Quantity {quantity} is not greater than or equal to zero"
                
        self.name = name
        self.price = price
        self.quantity = quantity
        
        Item.all.append(self)
        
    def calculate_total_price(self):
        return self.price * self.quantity
    
    def apply_discount(self):
        self.price = self.price * self.pay_rate
    
    @classmethod
    def instantiate_from_csv(cls):
        with open('items.csv', 'r') as f:
            reader = csv.DictReader(f)
            items = list(reader)
        
        for item in items:
            Item(
                name = item.get("name"),
                price = float(item.get("price")),
                quantity = int(item.get("quantity"))
            )
            
    @staticmethod
    def is_integer(num):
        if isinstance(num, float):
            return num.is_integer()
        
        elif isinstance(num, int):
            return True
        
        else:
            return False
            
            
    def __repr__(self):
        return f"{self.__class__.__name__}('{self.name}', '{self.price}', '{self.quantity}')"

    
class Phone(Item):
    def __init__(self, name: str, price: float, quantity = 0, broken_phones = 0):
        super().__init__(name, price, quantity)
        
        assert broken_phones >= 0, f"Price {broken_phones} is not greater than or equal to zero" 
        
        self.broken_phones = broken_phones
    
phone1 = Phone("iphone14", 1000, 5, 1)
Item1 = Item("gamepad", 50, 10)

phone1.calculate_total_price()
print(Item.all)

#inheritance ile child classlar oluşturabiliriz.
#parent classın tüm method ve attributelerını alır.
#super().__init__ fonksiyonu ile kodları tekrar yazmamıza gerek kalmaz.
#repr methodunda {self.__class__.__name__} kullanırsak classa özel bir yazdırma işlemi yapabiliriz.
# Out:
# [Phone('iphone14', '1000', '5'), Item('gamepad', '50', '10')]

# %%
class Item:
    pay_rate = 0.8
    all = []
    def __init__(self, name: str, price: float, quantity = 0):
        assert price >= 0, f"Price {price} is not greater than or equal to zero" 
        assert quantity >= 0, f"Quantity {quantity} is not greater than or equal to zero"
                
        self.name = name
        self.price = price
        self.quantity = quantity
        
        Item.all.append(self)
    
    @property
    def name(self):
        return self.__name
    
    @name.setter
    def name(self, value):
        if len(value) > 10:
            raise Exception("The name is too long")
        else:
            self.__name = value
    
    def calculate_total_price(self):
        return self.price * self.quantity
    
    def apply_discount(self):
        self.price = self.price * self.pay_rate
    
    @classmethod
    def instantiate_from_csv(cls):
        with open('items.csv', 'r') as f:
            reader = csv.DictReader(f)
            items = list(reader)
        
        for item in items:
            Item(
                name = item.get("name"),
                price = float(item.get("price")),
                quantity = int(item.get("quantity"))
            )
            
    @staticmethod
    def is_integer(num):
        if isinstance(num, float):
            return num.is_integer()
        
        elif isinstance(num, int):
            return True
        
        else:
            return False
            
            
    def __repr__(self):
        return f"{self.__class__.__name__}('{self.name}', '{self.price}', '{self.quantity}')"
    
    
item1 = Item("MyItem", 750)

#setting attribute
item1.name = "OtherItem"

#getting attribute
print(item1.name)

#property decaratörü ile aldığımız ismi bir daha normal şekilde değiştirmemeye yarar.
#name.setter ile property olsa bile ismi değiştirmemize yarar.
#self._name de kullanabiliriz ama self.__name kullanmak daha iyi olacaktır.
#eğer Item classı başka bir dosyada ise From dosyaadı import Item ile kullanbiliriz.
# Out:
# OtherItem

# %%
#ENCAPSULATION

class Item:
    pay_rate = 0.8
    all = []
    def __init__(self, name: str, price: float, quantity = 0):
        assert price >= 0, f"Price {price} is not greater than or equal to zero" 
        assert quantity >= 0, f"Quantity {quantity} is not greater than or equal to zero"
                
        self.__name = name
        self.__price = price
        self.quantity = quantity
        
        Item.all.append(self)
    
    @property
    def price(self):
        return self.__price
    
    def apply_discount(self):
        self.__price = self.__price * self.pay_rate
    
    def apply_increment(self, increment_value):
        self.__price = self.__price + self.__price * increment_value
    
    @property
    def name(self):
        return self.__name
    
    @name.setter
    def name(self, value):
        if len(value) > 10:
            raise Exception("The name is too long")
        else:
            self.__name = value
    
    def calculate_total_price(self):
        return self.__price * self.quantity
    
    @classmethod
    def instantiate_from_csv(cls):
        with open('items.csv', 'r') as f:
            reader = csv.DictReader(f)
            items = list(reader)
        
        for item in items:
            Item(
                name = item.get("name"),
                price = float(item.get("price")),
                quantity = int(item.get("quantity"))
            )
            
    @staticmethod
    def is_integer(num):
        if isinstance(num, float):
            return num.is_integer()
        
        elif isinstance(num, int):
            return True
        
        else:
            return False
            
            
    def __repr__(self):
        return f"{self.__class__.__name__}('{self.name}', '{self.price}', '{self.quantity}')"
    

item1 = Item("MyItem", 750)

item1.apply_discount()
item1.apply_increment(0.3)

item1.price

#price değerini encapsulation yaptığım için her price'ın başına dunder koydum.
# Out:
# 780.0

# %%
#ABSTRACTION
#gerekli bilgileri gösteren, gereksiz bilgileri gizleyen
#bir mail göndermek için arkada belli başlı işlemler olması gerekir.
#burda amacımız bunu tek fonksiyona indirirek diğer gereksiz bilgilerden kurtulcaz.
#gereksiz bilgileri instancelerden gizle.
#connect, prepare_body ve send methodlarını özel methodlara çevirerek bu işlemi yapabiliriz.
#methodların başına dunder ekle.

class Item:
    pay_rate = 0.8
    all = []
    def __init__(self, name: str, price: float, quantity = 0):
        assert price >= 0, f"Price {price} is not greater than or equal to zero" 
        assert quantity >= 0, f"Quantity {quantity} is not greater than or equal to zero"
                
        self.__name = name
        self.__price = price
        self.quantity = quantity
        
        Item.all.append(self)
    
    @property
    def price(self):
        return self.__price
    
    def apply_discount(self):
        self.__price = self.__price * self.pay_rate
    
    def apply_increment(self, increment_value):
        self.__price = self.__price + self.__price * increment_value
    
    @property
    def name(self):
        return self.__name
    
    @name.setter
    def name(self, value):
        if len(value) > 10:
            raise Exception("The name is too long")
        else:
            self.__name = value
    
    def calculate_total_price(self):
        return self.__price * self.quantity
    
    @classmethod
    def instantiate_from_csv(cls):
        with open('items.csv', 'r') as f:
            reader = csv.DictReader(f)
            items = list(reader)
        
        for item in items:
            Item(
                name = item.get("name"),
                price = float(item.get("price")),
                quantity = int(item.get("quantity"))
            )
            
    @staticmethod
    def is_integer(num):
        if isinstance(num, float):
            return num.is_integer()
        
        elif isinstance(num, int):
            return True
        
        else:
            return False
       
    def __connect(self, smtp_server):
        pass
    
    def __prepare_body(self):
        return f"""
        Hello bla bla bla
        """
    
    def __send(self):
        pass
    
    def send_email(self):
        self.__connect('')
        self.__prepare_body()
        self.__send()
            
    def __repr__(self):
        return f"{self.__class__.__name__}('{self.name}', '{self.price}', '{self.quantity}')"
    

item1 = Item("MyItem", 750)

item1.send_email()

#auto complation yaptığımızda bu üç fonkisyon gözükmeyecektir.

# %%
#INHERITANCE
#Zaten bunu daha önce gördük. Yukarıdaki cellerden bulabilirsin.

# %%
#POLYMORPHISM
#Çağırdığımız bir varlığın farklı senaryolara sahip olabilme yeteneğidir.

#example

name = "Emrullah"
print(len(name))

list1 = ["Emrullah","Ataklı"]
print(len(list1))

#That's polymorphism in action, a single function does now
#how to handle different kinds of objects as expected.

#Ayrıca inheritance yapıp parent classın methodunu child classta kullanmak da polimorphismdir.
#Bir varlığı farklı yerlerde kullanıyoruz.
#örnek olarak apply_discountu parent classta 0.2 olarak kullanırken child classta 0.3 olarak kullanmak.
# Out:
# 8
# 2
